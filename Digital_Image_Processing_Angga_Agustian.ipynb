# %%
#Name   : Angga Agustian
#Class  : TI22T
#SID    : 20220040114

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/img.jpg',0)

# %%
equ = cv2.equalizeHist(img)

# %%
if img is None:
  print("Error: Could not read the image. Please check the file path.")
else:
  # Apply histogram equalization
  equ = cv2.equalizeHist(img)

# %%
plt.subplot(121), plt.imshow(img, cmap= 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(equ, cmap= 'gray')
plt.title('Equalized Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/duckss.jpg')

# %%
mean = 0
sigma = 25
gaussian_noise = np.random.normal(mean, sigma, img.shape).astype(np.uint8)
noisy_img =cv2.add(img, gaussian_noise)

# %%
blurred = cv2.GaussianBlur(noisy_img, (5, 5),0)

# %%
img_rgb= cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
noisy_img_rgb = cv2.cvtColor(noisy_img, cv2.COLOR_BGR2RGB)
blurred_rgb = cv2.cvtColor(blurred, cv2.COLOR_BGR2RGB)

# %%
plt.subplot(1, 3, 1)
plt.imshow(img_rgb)
plt.title('Real Image')
plt.axis('off')
plt.subplot(1, 3, 2)
plt.imshow(noisy_img_rgb)
plt.title('Noisy Image')
plt.axis('off')
plt.subplot(1, 3, 3)
plt.imshow(blurred_rgb)
plt.title('Blurred Image')
plt.axis('off')
# Out:
# (-0.5, 235.5, 235.5, -0.5)

# %%
plt.subplot(1, 2, 2)
plt.imshow(blurred_rgb)
plt.title('Blurred Image')
plt.axis('off')
# Out:
# (-0.5, 235.5, 235.5, -0.5)

# %%
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/cat.jpg', 0)

# %%
sobelx = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=5)  # Sobel X
sobely = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=5)  # Sobel Y

# %%
sobelx= cv2.convertScaleAbs(sobelx)
sobely= cv2.convertScaleAbs(sobely)

# %%
plt.figure(figsize=(10,5))

# %%
plt.subplot(1, 2, 1)
plt.imshow(sobelx, cmap='gray')
plt.title('Sobel X ')
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(sobely, cmap='gray')
plt.title('Sobel Y')
plt.axis('off')
# Out:
# (-0.5, 2999.5, 3998.5, -0.5)

# %%
plt.show()

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/kitten.jpg')
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(img2)
plt.axis('on')

plt.subplot(1, 2, 2)
downsampled_img = cv2.resize(img2, (128, 128))
plt.title('Resized Image')
plt.imshow(downsampled_img)
plt.axis('on')
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/lachesiss.jpg')
img3 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(img3)
plt.axis('on')
plt.subplot(1,2,2)
upsampled_img = cv2.resize(img3, (3840, 2160))
plt.title('Upsampled Image')
plt.imshow(upsampled_img)
plt.axis('on')
# Out:
# (-0.5, 3839.5, 2159.5, -0.5)

# %%
original_image = cv2.imread('/content/drive/MyDrive/Colab Notebooks/cat.jpg', cv2.IMREAD_GRAYSCALE)
if original_image is None:
        raise ValueError("Could not load the image. Please check the path.")

equalized_image = cv2.equalizeHist(original_image)
hist_original = cv2.calcHist([original_image], [0], None, [256], [0, 256])
hist_equalized = cv2.calcHist([equalized_image], [0], None, [256], [0, 256])
plt.figure(figsize=(12, 6))
plt.subplot(2, 2, 1)
plt.imshow(original_image, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(2, 2, 2)
plt.plot(hist_original)
plt.title('Original Histogram')
plt.xlim([0, 256])

plt.subplot(2, 2, 3)
plt.imshow(equalized_image, cmap='gray')
plt.title('Equalized Image')
plt.axis('off')

plt.subplot(2, 2, 4)
plt.plot(hist_equalized)
plt.title('Equalized Histogram')
plt.xlim([0, 256])
plt.show()

# %%
original_stats = {
        'min': original_image.min(),
        'max': original_image.max(),
        'mean': original_image.mean(),
        'std': original_image.std()
    }

equalized_stats = {
        'min': equalized_image.min(),
        'max': equalized_image.max(),
        'mean': equalized_image.mean(),
        'std': equalized_image.std()
    }

print("Original Image Statistics:")
for stat, value in original_stats.items():
    print(f"{stat}: {value}")

print("\nEqualized Image Statistics:")
for stat, value in equalized_stats.items():
    print(f"{stat}: {value}")
# Out:
# Original Image Statistics:
# min: 0
# max: 255
# mean: 132.72502925731433
# std: 71.57246829762207
#
# Equalized Image Statistics:
# min: 0
# max: 255
# mean: 127.90651279486538
# std: 73.82890504379543

# %%
def calculate_contrast_improvement(original_image, equalized_image):
    original_mean = original_image.mean()
    equalized_mean = equalized_image.mean()
    contrast_improvement = (equalized_mean - original_mean) / original_mean
    return contrast_improvement

contrast_improvement = calculate_contrast_improvement(original_image, equalized_image)
print(f"Contrast Improvement: {contrast_improvement * 100:.2f}%")
# Out:
# Contrast Improvement: -3.63%
